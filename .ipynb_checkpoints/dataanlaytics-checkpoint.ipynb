# %%
import pandas as pd #데이터분석
import numpy as np #행렬이나 일반적으로 대규모 다차원 배열을 처리
import matplotlib as mpl
import matplotlib.pyplot as plt
import datetime #타임스탬프가 특정시간으로나오게

# %%
data = pd.read_excel('data.xlsx')#연습용xlsx
#data = pd.read_excel('O_Retail.xlsx')
data[0:]
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                 WHITE METAL LANTERN         6
# 2      536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
# 3      536366     22633              HAND WARMER UNION JACK         6
# 4      536366     22632           HAND WARMER RED POLKA DOT         6
# 5      536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 6      536367     22745          POPPY'S PLAYHOUSE BEDROOM          6
# 7      536367     22748           POPPY'S PLAYHOUSE KITCHEN         6
# 8      536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 9      536370     22728           ALARM CLOCK BAKELIKE RED         24
# 10     536371    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010-12-01 08:28:00       1.85       17850  United Kingdom
# 4  2010-12-01 08:28:00       1.85       17850  United Kingdom
# 5  2010-12-01 08:34:00       1.69       13047  United Kingdom
# 6  2010-12-01 08:34:00       2.10       13047  United Kingdom
# 7  2010-12-01 08:34:00       2.10       13047  United Kingdom
# 8  2010-12-01 08:45:00       3.75       12583          France
# 9  2010-12-01 08:45:00       3.75       12583          France
# 10 2010-12-01 08:26:00       2.75       12583          France

# %%
#데이터 송장기준으로 분류 완료!

value=[]
value1=[]
value2=[]
dir={}

No = data['InvoiceNo']
for i in range(0,len(No)):
    value2.append(data['StockCode'][i])
    value2.append(data['Description'][i])
    value2.append(data['Quantity'][i])
    value2.append(data['UnitPrice'][i])
    if (i == len(No)-1) or (No[i] != No[i+1]):
        value.append(data['InvoiceDate'][i])
        value.append(data['CustomerID'][i])
        value.append(data['Country'][i])
        dir[No[i]]=value+[value2]
        print(No[i],dir[No[i]])
        value=[]
        value2=[]
        print("/")
    else:
        pass;
print(dir)
# Out:
# 536365 [Timestamp('2010-12-01 08:26:00'), 17850, 'United Kingdom', ['85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 6, 2.55, 71053, 'WHITE METAL LANTERN', 6, 3.39, '84406B', 'CREAM CUPID HEARTS COAT HANGER', 8, 2.75]]
# /
# 536366 [Timestamp('2010-12-01 08:28:00'), 17850, 'United Kingdom', [22633, 'HAND WARMER UNION JACK', 6, 1.85, 22632, 'HAND WARMER RED POLKA DOT', 6, 1.85]]
# /
# 536367 [Timestamp('2010-12-01 08:34:00'), 13047, 'United Kingdom', [84879, 'ASSORTED COLOUR BIRD ORNAMENT', 32, 1.69, 22745, "POPPY'S PLAYHOUSE BEDROOM ", 6, 2.1, 22748, "POPPY'S PLAYHOUSE KITCHEN", 6, 2.1]]
# /
# 536370 [Timestamp('2010-12-01 08:45:00'), 12583, 'France', [22728, 'ALARM CLOCK BAKELIKE PINK', 24, 3.75, 22728, 'ALARM CLOCK BAKELIKE RED ', 24, 3.75]]
# /
# 536371 [Timestamp('2010-12-01 08:26:00'), 12583, 'France', ['84406B', 'CREAM CUPID HEARTS COAT HANGER', 8, 2.75]]
# /
# {536365: [Timestamp('2010-12-01 08:26:00'), 17850, 'United Kingdom', ['85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 6, 2.55, 71053, 'WHITE METAL LANTERN', 6, 3.39, '84406B', 'CREAM CUPID HEARTS COAT HANGER', 8, 2.75]], 536366: [Timestamp('2010-12-01 08:28:00'), 17850, 'United Kingdom', [22633, 'HAND WARMER UNION JACK', 6, 1.85, 22632, 'HAND WARMER RED POLKA DOT', 6, 1.85]], 536367: [Timestamp('2010-12-01 08:34:00'), 13047, 'United Kingdom', [84879, 'ASSORTED COLOUR BIRD ORNAMENT', 32, 1.69, 22745, "POPPY'S PLAYHOUSE BEDROOM ", 6, 2.1, 22748, "POPPY'S PLAYHOUSE KITCHEN", 6, 2.1]], 536370: [Timestamp('2010-12-01 08:45:00'), 12583, 'France', [22728, 'ALARM CLOCK BAKELIKE PINK', 24, 3.75, 22728, 'ALARM CLOCK BAKELIKE RED ', 24, 3.75]], 536371: [Timestamp('2010-12-01 08:26:00'), 12583, 'France', ['84406B', 'CREAM CUPID HEARTS COAT HANGER', 8, 2.75]]}

# %%
#1.국가와제품

#dir[key][순번]= 하나씩불러오는 방법
# key = 송장
# 첫번째 = 송장시간, 고객번호, 국가 0 1 2 
# 두번째 = 제품번호, 상세 내용, 양, 단가 3.1,2,3,4- 이 순서대로 반복 -> 4로 나누어서 불러오면 될듯

# 송장과 고객번호, 제품번호만 불러오기

va=[]
count=1
dircandp={}

for i in list(dir.keys()):
    #print(i)
    #print(dir[i][2])
    a=dir[i][2]
    #0- 시간, 1- 고객번호, 2- 국가
    """"""
    for j in range(0,len(dir[i][3])) :
        if (j%4==0):
            #print("/",dir[i][3][j])
            va.append(dir[i][3][j])
            
#0-제품번호, 1-상세내용, 2-양, 3-단가
print(va)
vaa=[]#임시저장소
for i in range(0, len(va)):
    for j in range(i, len(va)):
        if(j==len(va)-1):
            va[i]=a,va[i],count
            count=1
        elif va[i]== va[j+1]:
            vaa.append(j+1)
            count=count+1
        else :
            continue;
for k in vaa:
    del va[k]
print(va)
""""""

for i in va:
    a=i[0]
    
    if a in dircandp.keys():
        v=dircandp[a]
        v.append([i[1],i[2]])
    else :
        dircandp[i[0]]=[i[1],i[2]]
    
print(dircandp)
# Out:
# ['85123A', 71053, '84406B', 22633, 22632, 84879, 22745, 22748, 22728, 22728, '84406B']
# [('France', '85123A', 1), ('France', 71053, 1), ('France', '84406B', 2), ('France', 22633, 1), ('France', 22632, 1), ('France', 84879, 1), ('France', 22745, 1), ('France', 22748, 1), ('France', 22728, 2)]
# {'France': ['85123A', 1, [71053, 1], ['84406B', 2], [22633, 1], [22632, 1], [84879, 1], [22745, 1], [22748, 1], [22728, 2]]}

# %%
#1.국가와제품

#그래프 그리기

# %%
#2.시간과 고객번호
# key = 송장
# 첫번째 = 송장시간, 고객번호, 국가 0 1 2 
# 두번째 = 제품번호, 상세 내용, 양, 단가 3.1,2,3,4- 이 순서대로 반복 -> 4로 나누어서 불러오면 될듯

# 송장과 시간, 고객번호만 불러오기

dirtandu={}
tandu=[]

print(dir.keys())
for i in dir:
    print(i)
    if i in dirtandu.keys():
        a=dirtandu[dir[i][1]]
        print(a)
        a.append(dir[i][0])
        print(a)
    else:
        dirtandu[dir[i][1]]=dir[i][0]
    #0- 시간, 1- 고객번호, 2- 국가

print(dirtandu)
# Out:
# dict_keys([536365, 536366, 536367, 536370, 536371])
# 536365
# 536366
# 536367
# 536370
# 536371
# {17850: Timestamp('2010-12-01 08:28:00'), 13047: Timestamp('2010-12-01 08:34:00'), 12583: Timestamp('2010-12-01 08:26:00')}

# %%
#2.시간과 고객번호

#그래프 그리기

# %%
# 3.고객번호와 제품
